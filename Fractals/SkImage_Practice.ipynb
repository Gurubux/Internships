# %% [markdown]
# ## [9 Powerful Tips and Tricks for Working with Image Data using skimage in Python](https://www.analyticsvidhya.com/blog/2019/09/9-powerful-tricks-for-working-image-data-skimage-python/)
#
# By Analytics Vidhya

# %% [markdown]
# ### Loading Images from skimage

# %%
from skimage.io import imread, imshow
from skimage import data

image = data.astronaut()
imshow(image)

# %% [markdown]
# ### Reading Images from our System using skimage

# %%
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
# %matplotlib inline

image_gray = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg', as_gray=True)
imshow(image_gray)

# %%
image_gray = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg', as_gray=True)
print(image_gray.shape)
print(image_gray)
# Out:
# (677, 677)
# [[0.52527686 0.52527686 0.52919843 ... 0.         0.         0.        ]
#  [0.52527686 0.52527686 0.52919843 ... 0.         0.         0.        ]
#  [0.52135529 0.52527686 0.52527686 ... 0.         0.         0.        ]
#  ...
#  [1.         1.         1.         ... 0.08592706 0.08592706 0.08592706]
#  [1.         1.         1.         ... 0.08592706 0.08984863 0.08984863]
#  [1.         1.         1.         ... 0.08592706 0.0937702  0.0937702 ]]

# %%
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
# %matplotlib inline

image_color = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg', as_gray=False)
print(image_color.shape)
imshow(image_color)
# Out:
# (677, 677, 3)

# %% [markdown]
# *Hence, grayscale images are often used to reduce the computational complexity. So if the size of your dataset is very large, you can choose to go for grayscale over colored.*

# %% [markdown]
# ### 2. Changing Image Format

# %%
from skimage.color import rgb2gray
img = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')
img_new = rgb2gray(img)

plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_new)
plt.title('Grayscale Format') 

plt.show()

# %%
from skimage.color import rgb2hsv
img = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')
img_new = rgb2hsv(img)

plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_new)
plt.title('HSV Format') 

plt.show()

# %% [markdown]
# ### 3. Resizing Images using skimage

# %%
from skimage.transform import resize
img = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')
#resize image
img_resized = resize(img, (300, 200))

#plot images
plt.subplot(121), imshow(img)
plt.title('Original Image')
plt.subplot(122), imshow(img_resized)
plt.title('Resized Image')
plt.show()

# %% [markdown]
# ### 4. Rescaling (Upscale/Downscale) Images using skimage

# %%
from skimage.transform import rescale
img = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')
img_rescaled = rescale(img, scale=(0.5, 0.5))


plt.subplot(121), imshow(img)
plt.title('Original Image')

plt.subplot(122), imshow(img_rescaled)
plt.title('Rescaled Image')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:23: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '

# %% [markdown]
# ### 5. Rotate an Image by Different Angles using skimage

# %%
from skimage.transform import rotate
image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')

image_rotated = rotate(image, angle=45)
imshow(image_rotated)

# %%
from skimage.transform import rotate
image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')

image_rotated = rotate(image, angle=45, resize=True)
imshow(image_rotated)

# %% [markdown]
# ### 6. Flip Images Horizontally and Vertically

# %% [markdown]
# NumPy provides functions flipud and fliplr for flipping the images across the horizontal and vertical axis respectively.

# %%
from numpy import fliplr, flipud
dog = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')
cat = data.astronaut()
dog_flip = fliplr(dog)
cat_flip = fliplr(cat)

plt.subplot(141), imshow(dog)
plt.subplot(142), imshow(dog_flip)
plt.subplot(143), imshow(cat)
plt.subplot(144), imshow(cat_flip)
plt.show()

# %% [markdown]
# ### 7. Crop Images

# %%
image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')

# selecting part of the image only 
cropped = image[100:(img.shape[0]-100),100:(img.shape[1]-100)]

plt.subplot(121), imshow(image)
plt.title('Original Image')
plt.subplot(122),imshow(cropped)
plt.title('Cropped Image')

plt.show()

# %% [markdown]
# ### 8. Altering Image Brightness using skimage

# %%
from skimage import exposure

#adjusting brightness
image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg')
image_bright = exposure.adjust_gamma(image, gamma=0.5,gain=1)
image_dark = exposure.adjust_gamma(image, gamma=1.5,gain=1)

# plotting images
plt.subplot(131), imshow(image)
plt.title('Original Image')

plt.subplot(132),imshow(image_bright)
plt.title('Bright Image')

plt.subplot(133),imshow(image_dark)
plt.title('Dark Image')

plt.show()

# %% [markdown]
# ### 9. Using Filters in skimage

# %%
from skimage.filters import median

image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg', as_gray=True)
image_median = median(image)

# plotting images
plt.subplot(121), imshow(image)
plt.title('Original Image')

plt.subplot(122),imshow(image_median)
plt.title('Smooth Image')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
from skimage.filters import sobel_h

image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg', as_gray=True)
image_sobelh = sobel_h(image)

# plotting images
plt.subplot(121), imshow(image)
plt.title('Original Image')

plt.subplot(122),imshow(image_sobelh)
plt.title('Horizontal Edge')

plt.show()

# %% [markdown]
# ## [3 Beginner-Friendly Techniques to Extract Features from Image Data using Python](https://www.analyticsvidhya.com/blog/2019/08/3-techniques-extract-features-from-image-data-machine-learning-python/)

# %% [markdown]
# ![alt text](https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2019/08/article-image-21.png)
# ![alt text](https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2019/08/article-image-31.png)

# %% [markdown]
# ### Reading Image Data in Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg', as_gray=True)
imshow(image)

# %%
#checking image shape 
image.shape, image
# Out:
# ((677, 677),
#  array([[0.52527686, 0.52527686, 0.52919843, ..., 0.        , 0.        ,
#          0.        ],
#         [0.52527686, 0.52527686, 0.52919843, ..., 0.        , 0.        ,
#          0.        ],
#         [0.52135529, 0.52527686, 0.52527686, ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [1.        , 1.        , 1.        , ..., 0.08592706, 0.08592706,
#          0.08592706],
#         [1.        , 1.        , 1.        , ..., 0.08592706, 0.08984863,
#          0.08984863],
#         [1.        , 1.        , 1.        , ..., 0.08592706, 0.0937702 ,
#          0.0937702 ]]))

# %% [markdown]
# ### Method #1: Grayscale Pixel Values as Features

# %%
features = np.reshape(image, (677* 677))

features.shape, features
# Out:
# ((458329,),
#  array([0.52527686, 0.52527686, 0.52919843, ..., 0.08592706, 0.0937702 ,
#         0.0937702 ]))

# %% [markdown]
# ### Method #2: Mean Pixel Value of Channels

# %%
image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg') 
image.shape
# Out:
# (677, 677, 3)

# %%
feature_matrix = np.zeros((677, 677)) 
feature_matrix.shape
# Out:
# (677, 677)

# %%
for i in range(0,image.shape[0]):
    for j in range(0,image.shape[1]):
        feature_matrix[i][j] = ((int(image[i,j,0]) + int(image[i,j,1]) + int(image[i,j,2]))/3)

# %%
feature_matrix.shape
# Out:
# (677, 677)

# %%
features = np.reshape(feature_matrix, (677*677)) 
features.shape
# Out:
# (458329,)

# %% [markdown]
# ### Method #3: Extracting Edge Features

# %%
#importing the required libraries
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

#reading the image 
image = imread('https://raw.githubusercontent.com/Gurubux/Transcript/master/MyImge_.jpg',as_gray=True)

#calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)
#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_vertical, cmap='gray')
