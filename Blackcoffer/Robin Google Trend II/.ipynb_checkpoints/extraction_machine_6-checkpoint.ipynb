# %%
# Kindly read instructions carefully. If any unexpected errors or doubts you can contact.

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
import time
import random
import os
import shutil
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver import Proxy
from selenium.webdriver.chrome.webdriver import WebDriver as ChromeDriver
from fake_useragent import UserAgent
from selenium.webdriver.support.wait import WebDriverWait
# If you see error here, install required package as described in Instructions file

# %%
# If you see error here, check path and name of file and folder
# The folder setup is also desccribed in Instructions file
df=pd.read_excel('./reference/url_machine_6.xlsx',header=None)

# %%
links=df[0].tolist()

# %%
# No change required here
# No Proxy
def newChromeBrowserDefault(headless=True, downloadPath=None):
    """ Helper function that creates a new Selenium browser """
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent="+UserAgent().random)
    if headless:
        options.add_argument('headless')
    if downloadPath is not None:
        prefs = {}
        if not os.path.exists(downloadPath):
            os.makedirs(downloadPath)
        prefs["profile.default_content_settings.popups"]=0
        prefs["download.default_directory"]=downloadPath
        options.add_experimental_option("prefs", prefs)

    browser = webdriver.Chrome(chrome_options=options, executable_path='C:\driver\chromedriver.exe')
    return browser

# %%
#### CHANGE HERE

# When using Code 2 in the cell below, you will need to provide a proxy
# 1) Visit https://www.sslproxies.org for new proxies

# 2) Replace proxy here in the given field and run this cell, before running Code 2

# With Proxy
def newChromeBrowserProxy(headless=True, downloadPath=None,proxy='5.206.233.106:35595'):
    """ Helper function that creates a new Selenium browser """
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent="+UserAgent().random)
    if headless:
        options.add_argument('headless')
    if downloadPath is not None:
        prefs = {}
        if not os.path.isdir(downloadPath):
            os.makedirs(downloadPath)
        prefs["profile.default_content_settings.popups"]=0
        prefs["download.default_directory"]=downloadPath
        options.add_experimental_option("prefs", prefs)

    settings = {
    "httpProxy": proxy,
    "sslProxy": proxy
    }
    proxy = Proxy(settings)
    from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
    cap = DesiredCapabilities.CHROME.copy()
    cap['platform'] = "WINDOWS"
    cap['version'] = "7"
    proxy.add_to_capabilities(cap)

    browser = ChromeDriver("C:\driver\chromedriver.exe",desired_capabilities=cap,chrome_options=options)
    return browser

# %%
len(links)==100000
# Out:
# False

# %%
#### CHANGE HERE
# Set download path here to 'all_data' folder as described in Instructions file
# Use '\\' to seperate path
downloadPath="E:\\Study\\Internship\\Blackcoffer\\Robin Google Trend II\\all_data"

# %%
#### CHANGE HERE AS DESCRIBED BELOW

# If you close the bot chrome window, you will need to run this cell again to launch new chrome window

# Only call one of the functions at a time below

# There is a 24 hour restriction on every IP/internet connection/4G network you are using after about 700 downloads
# When you reach that limit code will crash
# When you run for the first time every 24 hours run 'newChromeBrowserDefault' function and comment the other function call
# In other words, run Code 1 and comment Code 2

# Code 1
#driver = newChromeBrowserDefault(headless=False,downloadPath=downloadPath)


# Whenever limit is reached for your internet connection either change the network or to continue using the same network for further 
# downloads use the below second method with proxy
# To run second method uncomment call to 'newChromeBrowserProxy' and comment call to 'newChromeBrowserDefault'
# In other words, run Code 2 and comment Code 1

# Note: Before running Code 2, replace proxy in function definition in above cell

# Code 2
driver = newChromeBrowserProxy(headless=False,downloadPath=downloadPath)
# Out:
# C:\Users\Guru\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: use options instead of chrome_options

# %%
#### KEY POINTS TO KNOW
# 1) Most of the proxies that you will try using Code 2 would be banned by google, so the code below will crash for those particular 
#    proxies. You will have to replace and try a few proxies before you get one that is usable.
# 2) A new google chrome window will open that will be operated by our automated bot.
#    REMEMBER: Do not minimize that chrome window which is being operated by bot or else it will crash
# 3) When a trying proxy and after you see a crash in the code below. To verify that proxy actually is not loading any data, try 
#    refreshing the window few times to see if it responds. If it works, try running code again, otherwise change proxy.
# 4) When there is no error and the code is still running, do not interfere with bot chrome window or any files in the all_data folder
# 
# 5) In general, as very few percentage of proxies work, if you have an alternate internet connection we recommend that you use it
#    until it's limit is reached as compared to using a proxy. Once you have used up your daily limit of ~700 downloads for each 
#    network then use the the proxy method

# %%
# No change required here
def get_time(downloadPath):
    return max([os.path.getmtime(os.path.join(downloadPath, f)) for f in os.listdir(downloadPath) if os.path.isfile(os.path.join(downloadPath, f))], default=0)

def download_done_chk1(downloadPath):
    for f in os.listdir(downloadPath):
        if (".tmp" in f) or (".crdownload" in f) or (".part" in f):
            time.sleep(0.5)
            print("in recursion 1")
            download_done_chk1(downloadPath)
    
def download_done_chk2(previous_mtime):
    new_mtime=get_time(downloadPath)
    if new_mtime==previous_mtime:
        time.sleep(0.5)
        print("in recursion 2")
        download_done_chk2(previous_mtime)
    elif new_mtime<previous_mtime:
        print("unexpected error")

# %%
# Machine 6
# Following are index values
# Batch range that you have to run: 400000-499999

# %%
# CHANGE HERE
# When running for the very first time no change is required
# When one or more files have been downloaded in the all_data folder and the code crashes, 
# then YOU NEED TO MAKE CHANGE TO OFFSET BEFORE EXECUTING THIS CELL AGAIN

# How to make change:
# Look at the last file number that has been downloaded and change offset as described below.
# For example, let's say the name of latest file downloaded is data_400010.csv
# In that case, the offset for the next run would be 400011

# In other words, offset for next run would be last file number + 1

# Only offset value has to be changed. No other changes should be made.

# Give a little extra caution while modifying offset as it would be difficult for us to handle any errors later in the process

offset=400100
previous_mtime=get_time(downloadPath)

for idx,link in enumerate(links[offset-400000:100]):
    driver.get(link.replace('.nl','.com'))
    try:
        element = WebDriverWait(driver, 10).until(lambda x: x.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]'))
    except:
        driver.refresh()
        try:
            element = WebDriverWait(driver, 10).until(lambda x: x.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]'))
        except:
            print("Exception occured: Verify if the daily limit is reached on current network.")
            
    print("Ready to download")
    element.click()
    download_done_chk1(downloadPath)
    download_done_chk2(previous_mtime)
    filename = max([os.path.join(downloadPath, f) for f in os.listdir(downloadPath) if os.path.isfile(os.path.join(downloadPath, f))], key=os.path.getmtime)
    shutil.move(filename,downloadPath+'\\'+"data"+"_"+str((offset+idx))+'.csv')
    previous_mtime=get_time(downloadPath)
    print(idx)
    print(link)
    print("Success")
# Out:
# Ready to download
# in recursion 2
# 0
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDIT
# Success
# Ready to download
# in recursion 1
# 1
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDMCQ
# Success
# Ready to download
# in recursion 1
# 2
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDN
# Success
# Ready to download
# in recursion 1
# 3
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDNT
# Success
# Ready to download
# in recursion 1
# 4
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDR
# Success
# Ready to download
# in recursion 1
# 5
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDRY
# Success
# Ready to download
# in recursion 1
# 6
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDSFF
# Success
# Ready to download
# in recursion 1
# 7
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDU
# Success
# Ready to download
# in recursion 1
# 8
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EDUC
# Success
# Ready to download
# in recursion 1
# 9
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EE
# Success
# Ready to download
# in recursion 1
# 10
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EEA
# Success
# Ready to download
# in recursion 1
# 11
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EEFT
# Success
# Ready to download
# in recursion 1
# 12
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EEI
# Success
# Ready to download
# in recursion 1
# 13
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EEP
# Success
# Ready to download
# in recursion 1
# 14
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EEQ
# Success
# Ready to download
# in recursion 1
# 15
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EEX
# Success
# Ready to download
# in recursion 1
# 16
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EF
# Success
# Ready to download
# in recursion 1
# 17
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFBI
# Success
# Ready to download
# in recursion 1
# 18
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFC
# Success
# Ready to download
# in recursion 1
# 19
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFF
# Success
# Ready to download
# in recursion 1
# 20
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFII
# Success
# Ready to download
# in recursion 1
# 21
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFJI
# Success
# Ready to download
# in recursion 1
# 22
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFL
# Success
# Ready to download
# in recursion 1
# 23
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFOI
# Success
# Ready to download
# in recursion 1
# 24
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFR
# Success
# Ready to download
# in recursion 1
# 25
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFSC
# Success
# Ready to download
# in recursion 1
# 26
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFT
# Success
# Ready to download
# in recursion 1
# 27
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFUT
# Success
# Ready to download
# in recursion 1
# 28
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EFX
# Success
# Ready to download
# in recursion 1
# 29
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGAN
# Success
# Ready to download
# in recursion 1
# 30
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGAS
# Success
# Ready to download
# in recursion 1
# 31
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGBN
# Success
# Ready to download
# in recursion 1
# 32
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGC
# Success
# Ready to download
# in recursion 1
# 33
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGF
# Success
# Ready to download
# in recursion 2
# 34
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGHT
# Success
# Ready to download
# in recursion 1
# 35
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGI
# Success
# Ready to download
# in recursion 1
# 36
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGL
# Success
# Ready to download
# in recursion 1
# 37
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGLE
# Success
# Ready to download
# in recursion 1
# 38
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGN
# Success
# Ready to download
# in recursion 1
# 39
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGO
# Success
# Ready to download
# in recursion 1
# 40
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGOV
# Success
# Ready to download
# in recursion 1
# 41
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGP
# Success
# Ready to download
# in recursion 1
# 42
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGRX
# Success
# Ready to download
# in recursion 1
# 43
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGT
# Success
# Ready to download
# in recursion 1
# 44
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EGY
# Success
# Ready to download
# in recursion 1
# 45
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EHC
# Success
# Ready to download
# in recursion 1
# 46
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EHI
# Success
# Ready to download
# in recursion 1
# 47
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EHIC
# Success
# Ready to download
# in recursion 1
# 48
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EHTH
# Success
# Ready to download
# in recursion 1
# 49
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIA
# Success
# Ready to download
# in recursion 1
# 50
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIDX
# Success
# Ready to download
# in recursion 1
# 51
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIG
# Success
# Ready to download
# in recursion 1
# 52
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIGI
# Success
# Ready to download
# in recursion 1
# in recursion 1
# 53
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIGR
# Success
# Ready to download
# in recursion 1
# 54
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIHI
# Success
# Ready to download
# in recursion 1
# 55
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIM
# Success
# Ready to download
# in recursion 1
# 56
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIO
# Success
# Ready to download
# in recursion 1
# 57
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIP
# Success
# Ready to download
# in recursion 1
# 58
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIV
# Success
# Ready to download
# in recursion 1
# 59
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EIX
# Success
# Ready to download
# in recursion 1
# 60
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EJ
# Success
# Ready to download
# in recursion 1
# 61
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EKSO
# Success
# Ready to download
# in recursion 1
# 62
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EL
# Success
# Ready to download
# in recursion 1
# 63
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELAN
# Success
# Ready to download
# in recursion 1
# 64
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELCI
# Success
# Ready to download
# in recursion 1
# 65
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELEC
# Success
# Ready to download
# in recursion 1
# 66
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELF
# Success
# Ready to download
# in recursion 1
# 67
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELGX
# Success
# Ready to download
# in recursion 1
# 68
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELLH
# Success
# Ready to download
# in recursion 1
# 69
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELLI
# Success
# Ready to download
# in recursion 1
# 70
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELLO
# Success
# Ready to download
# in recursion 1
# 71
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELMD
# Success
# Ready to download
# in recursion 1
# 72
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELMG
# Success
# Ready to download
# in recursion 1
# 73
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELN
# Success
# Ready to download
# in recursion 1
# 74
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELNK
# Success
# Ready to download
# in recursion 1
# 75
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELON
# Success
# Ready to download
# in recursion 1
# 76
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELOQ
# Success
# Ready to download
# in recursion 1
# 77
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELOS
# Success
# Ready to download
# in recursion 1
# 78
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELOX
# Success
# Ready to download
# in recursion 1
# 79
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELP
# Success
# Ready to download
# in recursion 1
# 80
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELRC
# Success
# Ready to download
# in recursion 1
# 81
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELRNF
# Success
# Ready to download
# in recursion 1
# 82
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELS
# Success
# Ready to download
# in recursion 1
# 83
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELSE
# Success
# Ready to download
# in recursion 1
# 84
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELTK
# Success
# Ready to download
# in recursion 1
# 85
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELTTY
# Success
# Ready to download
# in recursion 1
# 86
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELVT
# Success
# Ready to download
# in recursion 1
# 87
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELX
# Success
# Ready to download
# in recursion 1
# 88
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=ELY
# Success
# Ready to download
# in recursion 1
# 89
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EM
# Success
# Ready to download
# in recursion 1
# 90
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMAN
# Success
# Ready to download
# in recursion 1
# 91
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMC
# Success
# Ready to download
# in recursion 1
# 92
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMCF
# Success
# Ready to download
# in recursion 1
# 93
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMCI
# Success
# Ready to download
# in recursion 1
# 94
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMD
# Success
# Ready to download
# in recursion 1
# 95
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EME
# Success
# Ready to download
# in recursion 1
# 96
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMES
# Success
# Ready to download
# in recursion 1
# 97
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMF
# Success
# Ready to download
# in recursion 1
# 98
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMGC
# Success
# Ready to download
# in recursion 1
# 99
# https://trends.google.nl/trends/explore?cat=107&date=2014-01-01%202014-01-31&geo=US&q=EMI
# Success

# %%
len(links[400100-400100:10000])
# Out:
# 100
